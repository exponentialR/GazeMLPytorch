# %%
import sys
import os 
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import cv2
import numpy as np
import matplotlib.pyplot as plt 
from data.unityeyes import UnityEyesDataset

# %%
dataset = UnityEyesDataset()
sample = dataset[0]

# %%
plt.imshow(sample['full_image'])

# %%
heatmaps = sample['heatmaps']

# %%
merged_heatmaps = np.mean(heatmaps[16:33], axis = 0)

# %%
plt.imshow(merged_heatmaps)

# %%
plt.imshow(sample['img'])

# %%
sample['landmarks']
# Out:
# array([[43.383198 , 39.757195 ],
#        [39.12692  , 37.102634 ],
#        [30.84479  , 42.22473  ],
#        [21.226465 , 53.46109  ],
#        [19.017145 , 67.42555  ],
#        [25.201057 , 77.90855  ],
#        [32.214615 , 84.1301   ],
#        [39.53535  , 86.63825  ],
#        [45.297768 , 86.73967  ],
#        [47.79135  , 86.200836 ],
#        [50.66633  , 83.15627  ],
#        [51.558395 , 77.0573   ],
#        [51.704437 , 69.26555  ],
#        [50.98383  , 59.10125  ],
#        [49.609077 , 48.215626 ],
#        [47.714638 , 42.024525 ],
#        [29.040962 , 46.722427 ],
#        [23.318052 , 47.182438 ],
#        [18.54292  , 49.89513  ],
#        [15.442526 , 54.447544 ],
#        [14.488913 , 60.146667 ],
#        [15.8272505, 66.12478  ],
#        [19.253801 , 71.471855 ],
#        [24.24685  , 75.37378  ],
#        [30.046312 , 77.236534 ],
#        [35.76926  , 76.776566 ],
#        [40.544395 , 74.06387  ],
#        [43.64475  , 69.51146  ],
#        [44.5984   , 63.812336 ],
#        [43.260025 , 57.834187 ],
#        [39.83351  , 52.48715  ],
#        [34.840427 , 48.58522  ],
#        [29.543652 , 61.979496 ],
#        [41.962864 , 51.07956  ]], dtype=float32)
